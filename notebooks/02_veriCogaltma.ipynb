# %%
# !pip install pretty_midi
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: C:\Users\melik\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import glob
import os
import pretty_midi

midi_files = glob.glob("../data/processed/chopin_midi/*.midi")
original_midi_files = []
for i in midi_files:
    if "shift" not in i:
        original_midi_files.append(i)
len(original_midi_files)

for midi_file in original_midi_files:
    for semitone in range(-5,7):
        if semitone == 0:
            continue
        pm = pretty_midi.PrettyMIDI(midi_file)
        for instrument in pm.instruments:
            for note in instrument.notes:
                note.pitch += semitone
        
        #versyionları kaydet
        new_filename = f"{os.path.basename(midi_file).replace('.midi', '')}-shift{semitone}.midi"
        pm.write(os.path.join("../data/processed/chopin_midi",new_filename))
len(os.listdir("../data/processed/chopin_midi"))
# Out:
# 2412
